# %%
#Design 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data
categories = ['Write Speed', 'Read Speed']
spark_times = [16.66, 7.19]
ignite_times = [14.99, 1.09]

# Create a bar plot for Write Speed and Read Speed
fig, ax = plt.subplots(figsize=(10, 6))

bar_width = 0.1
bar_padding = 0.10

index = range(len(categories))

bar1 = ax.bar(index, spark_times, bar_width, label='Apache Spark',color='#ff0000')
bar2 = ax.bar([i + bar_width for i in index], ignite_times, bar_width, label='Apache Ignite', color='#008080')

# Add labels, title, and legend
ax.set_xlabel('Databases')
ax.set_ylabel('Execution times in seconds')
#ax.set_title('Comparison of Apache Spark and Apache Ignite Write/Read Speeds')
ax.set_xticks([i + bar_width/2 for i in index])
ax.set_xticklabels(categories)
ax.legend()

# Display the values on top of the bars
for bar in [bar1, bar2]:
    for rect in bar:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
#fig.suptitle('Read/Write speed of Apache Spark and Apache Ignite', y=0.01, ha='center')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
spark_speed = [11.72, 8.79]
ignite_speed = [4.07, 0.5]

# Bar width
bar_width = 0.3
spacing = 0.1  # spacing between groups of bars
index = np.arange(len(categories))

# Plotting the bars
fig, ax = plt.subplots(figsize=(8, 6))
bar1 = ax.bar(index - spacing/2, spark_speed, bar_width, label='Apache Spark')
bar2 = ax.bar(index + bar_width + spacing/2, ignite_speed, bar_width, label='Apache Ignite')

# Adding labels
ax.set_xlabel('Metrics')
ax.set_ylabel('Speed (seconds)')
ax.set_title('Comparison of Apache Spark and Apache Ignite Write/Read Speed')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(categories)

# Adding legend
ax.legend()

# Display the values on top of the bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(bar1)
autolabel(bar2)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
spark_speed = [11.72, 8.79]
ignite_speed = [4.07, 0.5]

# Narrower bar width and adjusted bar positions
bar_width = 0.2
index = np.arange(len(categories))

# Plotting the bars with minimized gap
fig, ax = plt.subplots(figsize=(5, 5))
bar1 = ax.bar(index - bar_width/2, spark_speed, bar_width, label='Apache Spark')
bar2 = ax.bar(index + bar_width/2, ignite_speed, bar_width, label='Apache Ignite')

# Adding labels
#ax.set_xlabel('Databases')
ax.set_ylabel('Estimated time inseconds')
#ax.set_title('Comparison of Apache Spark and Apache Ignite Write/Read Speed')
ax.set_xticks(index)
ax.set_xticklabels(categories)

# Adding legend
ax.legend()

# Display the values on top of the bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(bar1)
autolabel(bar2)

# Remove extra x-axis ticks and labels
ax.tick_params(axis='x', which='both', bottom=False)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Memory Usage ', 'CPU Load ']
spark_values = [4, 0.3]
ignite_values = [2.8, 0.1]

# Bar width
bar_width = 0.2
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots()

# Create bars
spark_bars = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#e67e22')
ignite_bars = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#9b59b6')

# Add labels, title, and legend
#ax.set_xlabel('Databases')
ax.set_ylabel('Usage(%)')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories)
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(spark_bars)
add_labels(ignite_bars)
ax.set_yticks(np.arange(0, 6, 2))
#fig.suptitle('Comparison of Memory Usage and CPU Load', y=0.01, ha='center')


# Show the plot
plt.show()

# %%
#Second After

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Memory Usage ', 'CPU Load ']
spark_values = [3.2, 0.2]
ignite_values = [2.1, 0.1]

# Bar width
bar_width = 0.2
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots()

# Create bars
spark_bars = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#e67e22')
ignite_bars = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#9b59b6')

# Add labels, title, and legend
#ax.set_xlabel('Databases')
ax.set_ylabel('Usage(%)')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories)
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(spark_bars)
add_labels(ignite_bars)
ax.set_yticks(np.arange(0, 6, 2))
#fig.suptitle('Comparison of Memory Usage and CPU Load', y=0.01, ha='center')


# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
speedup_values = [2.8, 17.58]

# Bar width
bar_width = 0.3
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(3,4))

# Create bars
bars = ax.bar(bar_positions, speedup_values, bar_width, color=['#f1c40f', '#8e44ad'], edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Speedup Times')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories)
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        

ax.set_yticks(np.arange(0, 24, 2))

add_labels(bars)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
speedup_values = [2.8, 17.58]

# Bar width
bar_width = 0.3
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(6, 6))

# Create bars
bars = ax.bar(bar_positions, speedup_values, bar_width, color=['#f1c40f', '#8e44ad'], edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Speedup Times')
ax.set_xticks(bar_positions)
ax.set_xticklabels(['Apache Spark', 'Apache Ignite'])  # Updated labels
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset po
# Out:
#   Cell In[71], line 31
#     textcoords="offset po
#                ^
# SyntaxError: unterminated string literal (detected at line 31)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
speedup_values = [2.8, 17.58]

# Bar width
bar_width = 0.3
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(6, 6))

# Create bars
bars = ax.bar(bar_positions, speedup_values, bar_width, color=['#f1c40f', '#8e44ad'], edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Speedup Times')
ax.set_xticks(bar_positions)
ax.set_xticklabels(['Apache Spark', 'Apache Ignite'])  # Updated labels
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

ax.set_yticks(np.arange(0, 24, 2))

add_labels(bars)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
speedup_values = [2.3, 13.7]

# Bar width
bar_width = 0.3
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(3,4))

# Create bars
bars = ax.bar(bar_positions, speedup_values, bar_width, color=['#e91e63', '#008080'], edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Speedup Times')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories)
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        

ax.set_yticks(np.arange(0, 24, 2))

add_labels(bars)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Data
# categories = ['Write Speed', 'Read Speed']
# spark_speed = [11.72, 8.79]
# ignite_speed = [4.07, 0.5]

# # Narrower bar width and adjusted bar positions
# bar_width = 0.2
# index = np.arange(len(categories))

# # Plotting the bars with minimized gap
# fig, ax = plt.subplots(figsize=(5, 5))
# bar1 = ax.bar(index - bar_width/2, spark_speed, bar_width, label='Apache Spark', edgecolor='black', linewidth=2)
# bar2 = ax.bar(index + bar_width/2, ignite_speed, bar_width, label='Apache Ignite', edgecolor='black', linewidth=2)

# # Adding labels
# #ax.set_xlabel('Databases')
# ax.set_ylabel('Execution time in seconds',weight='bold')
# #ax.set_title('Comparison of Apache Spark and Apache Ignite Write/Read Speed')
# ax.set_xticks(index)
# ax.set_xticklabels(categories,weight='bold')

# # Adding legend
# ax.legend()

# # Display the values on top of the bars
# def autolabel(bars):
#     for bar in bars:
#         height = bar.get_height()
#         ax.annotate('{}'.format(height),
#                     xy=(bar.get_x() + bar.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')

# # autolabel(bar1)
# # autolabel(bar2)

# # Bold the borders
# for bar in bar1 + bar2:
#     bar.set_edgecolor('black')
#     bar.set_linewidth(2)

# # Remove extra x-axis ticks and labels
# ax.tick_params(axis='x', which='both', bottom=False)

# # Show the plot
# plt.tight_layout()
# plt.savefig("C:\\Users\\manor\\Downloads\\plot.svg",format='svg')
# plt.show()





import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
spark_speed = [16.66, 14.99]
ignite_speed = [7.19, 1.09]

# Narrower bar width and adjusted bar positions
bar_width = 0.2
index = np.arange(len(categories))

# Plotting the bars with minimized gap
fig, ax = plt.subplots(figsize=(6, 6))
bar1 = ax.bar(index - bar_width/2, spark_speed, bar_width, label='Apache Spark', edgecolor='black', linewidth=2)
bar2 = ax.bar(index + bar_width/2, ignite_speed, bar_width, label='Apache Ignite', edgecolor='black', linewidth=2)

# Adding labels
#ax.set_xlabel('Databases')
ax.set_ylabel('Execution time in seconds',weight='bold')
#ax.set_title('Comparison of Apache Spark and Apache Ignite Write/Read Speed')
ax.set_xticks(index)
ax.set_xticklabels(categories,weight='bold')

# Adding legend
ax.legend()

# Display the values on top of the bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# autolabel(bar1)
# autolabel(bar2)

# Bold the borders
for bar in bar1 + bar2:
    bar.set_edgecolor('black')
    bar.set_linewidth(2)

# Remove extra x-axis ticks and labels
ax.tick_params(axis='x', which='both', bottom=False)

# Show the plot
plt.tight_layout()
plt.savefig("C:\\Users\\manor\\Downloads\\After_Comparsion_Bt_Write_Read_speed.svg",format='svg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
spark_speed = [16.66, 14.99]
ignite_speed = [7.19, 1.09]

# Narrower bar width and adjusted bar positions
bar_width = 0.2
index = np.arange(len(categories))

# Plotting the bars with minimized gap
fig, ax = plt.subplots(figsize=(6, 6))
bar1 = ax.bar(index - bar_width/2, spark_speed, bar_width, label='Apache Spark', edgecolor='black', linewidth=2)
bar2 = ax.bar(index + bar_width/2, ignite_speed, bar_width, label='Apache Ignite', edgecolor='black', linewidth=2)

# Adding labels
#ax.set_xlabel('Databases')
ax.set_ylabel('Execution time in seconds',weight='bold')
#ax.set_title('Comparison of Apache Spark and Apache Ignite Write/Read Speed')
ax.set_xticks(index)
ax.set_xticklabels(categories,weight='bold')

# Adding legend
ax.legend()

# Display the values on top of the bars
def autolabel(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# autolabel(bar1)
# autolabel(bar2)

# Bold the borders
for bar in bar1 + bar2:
    bar.set_edgecolor('black')
    bar.set_linewidth(2)

# Remove extra x-axis ticks and labels
ax.tick_params(axis='x', which='both', bottom=False)

# Show the plot
plt.tight_layout()
plt.savefig("C:\\Users\\manor\\Downloads\\plot1.svg",format='svg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Memory Usage', 'CPU Load']
spark_values = [3.2, 0.2]
ignite_values = [2.1, 0.1]

# Bar width
bar_width = 0.2
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots()

# Create bars with bold borders
spark_bars = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#e67e22', edgecolor='black', linewidth=2)
ignite_bars = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#9b59b6', edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Usage (%)',weight='bold')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories,weight='bold')
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# add_labels(spark_bars)
# add_labels(ignite_bars)
ax.set_yticks(np.arange(0, 6, 2))

# Show the plot
plt.savefig("C:\\Users\\manor\\Downloads\\Before_Comparsion_Bt_Mem_CPU_Load.svg",format='svg')
plt.show()


# import matplotlib.pyplot as plt
# import numpy as np

# # Data
# categories = ['Memory Usage', 'CPU Load']
# spark_values = [4, 0.3]
# ignite_values = [2.8, 0.1]

# # Bar width
# bar_width = 0.2
# bar_positions = np.arange(len(categories))

# # Set up the figure and axis
# fig, ax = plt.subplots()

# # Create bars with bold borders
# spark_bars = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#e67e22', edgecolor='black', linewidth=2)
# ignite_bars = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#9b59b6', edgecolor='black', linewidth=2)

# # Add labels, title, and legend
# ax.set_ylabel('Usage (%)',weight='bold')
# ax.set_xticks(bar_positions)
# ax.set_xticklabels(categories,weight='bold')
# ax.legend()

# # Add data labels
# def add_labels(bars):
#     for bar in bars:
#         height = bar.get_height()
#         ax.annotate('%.2f' % height,
#                     xy=(bar.get_x() + bar.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')

# # add_labels(spark_bars)
# # add_labels(ignite_bars)
# ax.set_yticks(np.arange(0, 6, 2))

# # Show the plot
# plt.savefig("C:\\Users\\manor\\Downloads\\After_Comparsion_Bt_Mem_CPU_Load.svg",format='svg')
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Memory Usage', 'CPU Load']
spark_values = [4, 0.3]
ignite_values = [2.8, 0.1]

# Bar width
bar_width = 0.2
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots()

# Create bars with bold borders
spark_bars = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#e67e22', edgecolor='black', linewidth=2)
ignite_bars = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#9b59b6', edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Usage (%)')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories)
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(spark_bars)
add_labels(ignite_bars)
ax.set_yticks(np.arange(0, 6, 2))

# Show the plot
plt.savefig("C:\\Users\\manor\\Downloads\\Before_Comparsion_Bt_Mem_CPU_Load.svg",format='svg')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
speedup_values = [2.8, 17.58]

# Bar width
bar_width = 0.3
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(3,4))

# Create bars
bars = ax.bar(bar_positions, speedup_values, bar_width, color=['#f1c40f', '#8e44ad'], edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Speedup Times')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories)
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
        

ax.set_yticks(np.arange(0, 24, 2))

add_labels(bars)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
spark_values = [2.8, 17.58]
ignite_values = [1, 2.8]

# Bar width
bar_width = 0.3
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(6, 6))

# Create bars
bars_spark = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#f1c40f', edgecolor='black', linewidth=2)
bars_ignite = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#8e44ad', edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Speedup Times',weight='bold')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories)
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

ax.set_yticks(np.arange(0, 24, 2))

# Add labels for Apache Spark and Apache Ignite
ax.text(bar_positions[0] - bar_width/2, max(spark_values) + 1, '', ha='center', va='bottom',weight='bold')
ax.text(bar_positions[1] + bar_width/2, max(ignite_values) + 1, '', ha='center', va='bottom',weight='bold')

# add_labels(bars_spark)
# add_labels(bars_ignite)

# Show the plot
plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Data
# categories = ['Write Speed', 'Read Speed']
# spark_values = [2.3, 13.7]
# ignite_values = [1, 2.3]

# # Bar width
# bar_width = 0.3
# bar_positions = np.arange(len(categories))

# # Set up the figure and axis
# fig, ax = plt.subplots(figsize=(6, 6))

# # Create bars
# bars_spark = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#f1c40f', edgecolor='black', linewidth=2)
# bars_ignite = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#8e44ad', edgecolor='black', linewidth=2)

# # Add labels, title, and legend
# ax.set_ylabel('Speedup Times')
# ax.set_xticks(bar_positions)
# ax.set_xticklabels(categories)
# ax.legend()

# # Add data labels
# def add_labels(bars):
#     for bar in bars:
#         height = bar.get_height()
#         ax.annotate('%.2f' % height,
#                     xy=(bar.get_x() + bar.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom')

# ax.set_yticks(np.arange(0, 16, 2))

# # Add labels for Apache Spark and Apache Ignite
# ax.text(bar_positions[0] - bar_width/2, max(spark_values) + 1, '', ha='center', va='bottom')
# ax.text(bar_positions[1] + bar_width/2, max(ignite_values) + 1, '', ha='center', va='bottom')

# add_labels(bars_spark)
# add_labels(bars_ignite)

# # Show the plot
# plt.savefig("C:\\Users\\manor\\Downloads\\After_Write_Read_Speedup.svg",format='svg')
# plt.show()



import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['Write Speed', 'Read Speed']
spark_values = [2.3, 13.7]
ignite_values = [1, 2.3]

# Bar width
bar_width = 0.3
bar_positions = np.arange(len(categories))

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(6, 6))

# Create bars
bars_spark = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#f1c40f', edgecolor='black', linewidth=2)
bars_ignite = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#8e44ad', edgecolor='black', linewidth=2)

# Add labels, title, and legend
ax.set_ylabel('Speedup Times',weight='bold')
ax.set_xticks(bar_positions)
ax.set_xticklabels(categories,weight='bold')
ax.legend()

# Add data labels
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('%.2f' % height,
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom',weight='bold')

ax.set_yticks(np.arange(0, 24, 2))

# Add labels for Apache Spark and Apache Ignite
ax.text(bar_positions[0] - bar_width/2, max(spark_values) + 1, '', ha='center', va='bottom',weight='bold')
ax.text(bar_positions[1] + bar_width/2, max(ignite_values) + 1, '', ha='center', va='bottom',weight='bold')

# add_labels(bars_spark)
# add_labels(bars_ignite)

# Show the plot
plt.savefig("C:\\Users\\manor\\Downloads\\After_Write_Read_Speedup.svg",format='svg')
plt.show()






# import matplotlib.pyplot as plt
# import numpy as np

# # Data
# categories = ['Write Speed', 'Read Speed']
# spark_values = [2.8, 17.58]
# ignite_values = [1, 2.8]

# # Bar width
# bar_width = 0.3
# bar_positions = np.arange(len(categories))

# # Set up the figure and axis
# fig, ax = plt.subplots(figsize=(6, 6))

# # Create bars
# bars_spark = ax.bar(bar_positions - bar_width/2, spark_values, bar_width, label='Apache Spark', color='#f1c40f', edgecolor='black', linewidth=2)
# bars_ignite = ax.bar(bar_positions + bar_width/2, ignite_values, bar_width, label='Apache Ignite', color='#8e44ad', edgecolor='black', linewidth=2)

# # Add labels, title, and legend
# ax.set_ylabel('Speedup Times',weight='bold')
# ax.set_xticks(bar_positions)
# ax.set_xticklabels(categories,weight='bold')
# ax.legend()

# # Add data labels
# def add_labels(bars):
#     for bar in bars:
#         height = bar.get_height()
#         ax.annotate('%.2f' % height,
#                     xy=(bar.get_x() + bar.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom',weight='bold')

# ax.set_yticks(np.arange(0, 24, 2))

# # Add labels for Apache Spark and Apache Ignite
# ax.text(bar_positions[0] - bar_width/2, max(spark_values) + 1, '', ha='center', va='bottom',weight='bold')
# ax.text(bar_positions[1] + bar_width/2, max(ignite_values) + 1, '', ha='center', va='bottom',weight='bold')

# # add_labels(bars_spark)
# # add_labels(bars_ignite)

# # Show the plot
# plt.savefig("C:\\Users\\manor\\Downloads\\Before_Write_Read_Speedup.svg",format='svg')
# plt.show()
